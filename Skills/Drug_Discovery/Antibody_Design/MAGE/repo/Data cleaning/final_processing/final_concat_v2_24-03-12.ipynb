# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('./concat_inputs_preTag_v2_24-03-12.csv', index_col=0)
df2 = pd.read_csv('./nonSabdab_detagged_24-03-12.csv', index_col=0)

# %%
df2['antigen_seq'] = df2['detagged_ant']

# %%
final_df = pd.concat([df2, df1[df1['source'] == 'SAbDab']])[['antigen_seq', 'VH_AA', 'VL_AA', 'antigen_name', 'source']]

# %%
final_df.shape
# Out:
# (18648, 5)

# %%
final_df = final_df.dropna(subset=['antigen_seq', 'VH_AA', 'VL_AA'])

# %%
final_df[final_df['VL_AA'].isna()]
# Out:
# Empty DataFrame
# Columns: [antigen_seq, VH_AA, VL_AA, antigen_name, source]
# Index: []

# %%
final_df[final_df['VH_AA'].isna()]
# Out:
# Empty DataFrame
# Columns: [antigen_seq, VH_AA, VL_AA, antigen_name, source]
# Index: []

# %%
final_df[final_df['antigen_seq'].isna()]
# Out:
# Empty DataFrame
# Columns: [antigen_seq, VH_AA, VL_AA, antigen_name, source]
# Index: []

# %%
final_df = final_df[final_df['antigen_seq'].apply(len) > 20]
final_df.shape
# Out:
# (18512, 5)

# %%
# final_df[['antigen_name', 'antigen_seq']].drop_duplicates().to_clipboard()

# %%
final_df.to_csv('concat_input_df_detagged_v2_24-03-12.csv')
